# %%
import json
import os
import frame_parser
from src import dataio
from src import eval_fn
import glob
from pprint import pprint
# Out:
# Using TensorFlow backend.
# ###DEVICE: cuda

# %% [markdown]
# # Define task

# %%
srl = 'framenet'
language = 'en'
fnversion = 1.7

# %% [markdown]
# # Load data

# %%
trn, dev, tst = dataio.load_data(srl=srl, language=language, fnversion=fnversion, exem=False, info=True)
# Out:
# # of instances in trn: 19391
# # of instances in dev: 2272
# # of instances in tst: 6714
# data example: [['Greece', 'wildfires', 'force', 'thousands', 'to', '<tgt>', 'evacuate', '</tgt>'], ['_', '_', '_', '_', '_', '_', 'evacuate.v', '_'], ['_', '_', '_', '_', '_', '_', 'Escaping', '_'], ['O', 'O', 'O', 'B-Escapee', 'O', 'X', 'O', 'X']]

# %%
# Parsing Gold Data

def test_model(model_path, masking=True, language='en'):
#     torch.cuda.set_device(device)
    model = frame_parser.FrameParser(srl=srl,gold_pred=True, fnversion=fnversion,
                                     model_path=model_path, masking=masking, language=language)
    
    parsed_result = []
    for instance in tst:
#         torch.cuda.set_device(device)
        result = model.parser(instance)[0]
        parsed_result.append(result)
        
#         break
        
    return parsed_result
        
# parsed = test_model('/disk/frameBERT/models/joint/36/', language=language)

# %% [markdown]
# # Data format example

# %%
print('\ntest_data')
print(tst[0])

# print('\nparsed_data')
# print(parsed[0])
# Out:
# test_data
# [['<tgt>', 'December', '</tgt>', '1998'], ['_', 'December.n', '_', '_'], ['_', 'Calendric_unit', '_', '_'], ['X', 'B-Unit', 'X', 'B-Whole']]

# %% [markdown]
# # Evaluate Models

# %%
model_path = '/disk/frameBERT/models/frameid-fn17-wo-exem/'
models = glob.glob(model_path+'*')

result = {}

for model_path in models:
    print('model:', model_path)
    parsed_result = test_model(model_path, language=language)
    frameid, arg_precision, arg_recall, arg_f1, full_precision, full_recall, full_f1 = eval_fn.evaluate(tst, parsed_result, 
                                                                                                        fnversion=fnversion)
    
    d = {}
    d['frameid'] = frameid
    d['arg_precision'] = arg_precision
    d['arg_recall'] = arg_recall
    d['arg_f1'] = arg_f1
    d['full_precision'] = full_precision
    d['full_recall'] = full_recall
    d['full_f1'] = full_f1
    result[model_path] = d
    pprint(d)
    
#     break
    
# pprint(result)
# Out:
# model: /disk/frameBERT/models/frameid-fn17-wo-exem/0
# srl model: framenet
# language: en
# version: 1.7
# using viterbi: False
# using masking: True
# pretrained BERT: bert-base-multilingual-cased
# using TGT special token: True
# used dictionary:
# 	 /disk/frameBERT/frameBERT/src/../koreanframenet/resource/info/fn1.7_lu2idx.json
# 	 /disk/frameBERT/frameBERT/src/../koreanframenet/resource/info/fn1.7_lufrmap.json
# 	 /disk/frameBERT/frameBERT/src/../koreanframenet/resource/info/fn1.7_bio_frargmap.json
# ...loaded model path: /disk/frameBERT/models/frameid-fn17-wo-exem/0
# /disk/frameBERT/models/frameid-fn17-wo-exem/0
# ...model is loaded
# evaluation is complete: 0hour:0min:0sec
# {'arg_f1': 0,
#  'arg_precision': 0.0,
#  'arg_recall': 0.0,
#  'frameid': 1.0,
#  'full_f1': 0.3333333333333333,
#  'full_precision': 0.3333333333333333,
#  'full_recall': 0.3333333333333333}
# ../frameBERT/src/utils.py:290: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred_logits = sm(masked_logit).view(1,-1)
# ../frameBERT/src/utils.py:298: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred_logits = sm(masked_logit).view(1,-1)

# %%
# write file as csv format

lines = []
lines.append('epoch'+'\t'+'SenseID'+'\t'+'Arg_P'+'\t'+'Arg_R'+'\t'+'ArgF1'+'\t'+'full_P'+'\t'+'full_R'+'\t'+'full_F1')
for m in result:
    epoch = m.split('/')[-1]
    senseid = str(result[m]['frameid'])
    arg_p = str(result[m]['arg_precision'])
    arg_r = str(result[m]['arg_recall'])
    arg_f1 = str(result[m]['arg_f1'])
    full_p = str(result[m]['full_precision'])
    full_r = str(result[m]['full_recall'])
    full_f1 = str(result[m]['full_f1'])
    line = epoch+'\t'+senseid+'\t'+arg_p+'\t'+arg_r+'\t'+arg_f1+'\t'+full_p+'\t'+full_r+'\t'+full_f1
    lines.append(line)
    

fname = '/disk/frameBERT/eval_result/frameid-fn17-wo-exem.txt'
with open(fname, 'w') as f:
    for line in lines:
        f.write(line + '\n')
        
print('######')
print('\tlanguage:', language)
print('\tfnversion:', fnversion)
print('\teval result:')
pprint(result)
print('\n....is written at', fname)
# Out:
# ######
# 	language: en
# 	fnversion: 1.7
# 	eval result:
# {'/disk/frameBERT/models/frameid-fn17-wo-exem/0': {'arg_f1': 0,
#                                                    'arg_precision': 0.0,
#                                                    'arg_recall': 0.0,
#                                                    'frameid': 1.0,
#                                                    'full_f1': 0.3333333333333333,
#                                                    'full_precision': 0.3333333333333333,
#                                                    'full_recall': 0.3333333333333333}}
#
# ....is written at /disk/frameBERT/eval_result/frameid-fn17-wo-exem.txt
